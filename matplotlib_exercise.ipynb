# %% [markdown]
# # 【確認課題】Matplotlib

# %%
# 使うライブラリ
'''
python3.12以降を使用してる場合、japanize-matplotlibは使えません。
その場合、matplotlib-fontjaを使用してください。
'''
# !pip install matplotlib-fontja

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import japanize_matplotlib
japanize_matplotlib.japanize()
# import matplotlib_fontja

# %% [markdown]
# ## 1問目
# 使うcsvはhist_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問1](./imgs/matplotlib/plot_1.png)

# %%
hist_data = pd.read_csv('C:/Users/Cowlisa/PG/BasicPython/data/hist_data.csv ')
plt.hist(hist_data[['aデータ','bデータ']])
plt.title('aデータとbデータの温度に関する度数分布')
plt.xlabel('温度(℃)')
plt.ylabel('度数')
# Out:
# Text(0, 0.5, '度数')

# %% [markdown]
# ## 2問目
# 使うcsvはscatter_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問2](./imgs/matplotlib/plot_2.png)

# %%
scatter_data = pd.read_csv('C:/Users/Cowlisa/PG/BasicPython/data/scatter_data.csv')
plt.scatter(scatter_data['length (cm)'],scatter_data['width (cm)'])
plt.grid(True)
plt.xlabel("length(cm)")
plt.ylabel("width(cm)")
plt.title("クラス0～2のlengthとwidthに関する散布図")

for i in range(len(scatter_data)):
    if scatter_data["class"][i] == 0:
        plt.scatter(scatter_data['length (cm)'][i],scatter_data['width (cm)'][i],color = "r")
    elif scatter_data["class"][i] == 1:
        plt.scatter(scatter_data['length (cm)'][i],scatter_data['width (cm)'][i],color = "b")
    elif scatter_data["class"][i] == 2:
        plt.scatter(scatter_data['length (cm)'][i],scatter_data['width (cm)'][i],color = "g")

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 3問目
# 使うcsvはline_data.csvです。下に2つの画像を表示するコードを書いてください。

# %% [markdown]
# ![問3_1](./imgs/matplotlib/plot_3_1.png)

# %% [markdown]
# ![問3_2](./imgs/matplotlib/plot_3_2.png)

# %%
line_data = pd.read_csv('C:/Users/Cowlisa/PG/BasicPython/data/line_data.csv')
fig, ax = plt.subplots()
ax.plot(line_data['期間'],line_data['件数'], marker='o', label='marker=o')
plt.grid(True)
plt.xlabel('期間')
plt.ylabel("件数")
plt.title("期間ごとの件数の推移")
# Out:
# Text(0.5, 1.0, '期間ごとの件数の推移')

# %%
line_data = pd.read_csv('C:/Users/Cowlisa/PG/BasicPython/data/line_data.csv')
plt.bar(line_data['期間'],line_data['費用'])
plt.grid(True)
plt.xlabel('期間')
plt.ylabel("費用")
plt.title("期間ごとの費用の推移")
# Out:
# Text(0.5, 1.0, '期間ごとの費用の推移')
